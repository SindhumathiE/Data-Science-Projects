# %% [markdown]
# 1. Import Necessary Libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# 2. Uploading dataset

# %%
df=pd.read_csv("diabetes.csv")

# %%
df.head()
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %%
df.tail()
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763           10      101             76             48      180  32.9
# 764            2      122             70             27        0  36.8
# 765            5      121             72             23      112  26.2
# 766            1      126             60              0        0  30.1
# 767            1       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome
# 763                     0.171   63        0
# 764                     0.340   27        0
# 765                     0.245   30        0
# 766                     0.349   47        1
# 767                     0.315   23        0

# %%
df.sample(10)
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 263            3      142             80             15        0  32.4
# 550            1      116             70             28        0  27.4
# 13             1      189             60             23      846  30.1
# 171            6      134             70             23      130  35.4
# 48             7      103             66             32        0  39.1
# 748            3      187             70             22      200  36.4
# 90             1       80             55              0        0  19.1
# 287            1      119             86             39      220  45.6
# 412            1      143             84             23      310  42.4
# 293            1      128             48             45      194  40.5
#
#      DiabetesPedigreeFunction  Age  Outcome
# 263                     0.200   63        0
# 550                     0.204   21        0
# 13                      0.398   59        1
# 171                     0.542   29        1
# 48                      0.344   31        1
# 748                     0.408   36        1
# 90                      0.258   21        0
# 287                     0.808   29        1
# 412                     1.076   22        0
# 293                     0.613   24        1

# %%
df.shape
# Out:
# (768, 9)

# %%
# # diabetes_map = {True: 1, False: 0}
# # data['diabetes'] = data['diabetes'].map(diabetes_map)
# diabetes_true_count = len(data.loc[data['diabetes'] == True])
# diabetes_false_count = len(data.loc[data['diabetes'] == False])
# (diabetes_true_count,diabetes_false_count)

# %%
#list of all columns
df.dtypes
# Out:
# Pregnancies                   int64
# Glucose                       int64
# BloodPressure                 int64
# SkinThickness                 int64
# Insulin                       int64
# BMI                         float64
# DiabetesPedigreeFunction    float64
# Age                           int64
# Outcome                       int64
# dtype: object

# %%
#information of dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    int64
#  1   Glucose                   768 non-null    int64
#  2   BloodPressure             768 non-null    int64
#  3   SkinThickness             768 non-null    int64
#  4   Insulin                   768 non-null    int64
#  5   BMI                       768 non-null    float64
#  6   DiabetesPedigreeFunction  768 non-null    float64
#  7   Age                       768 non-null    int64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(2), int64(7)
# memory usage: 54.1 KB

# %%
#statistical summary
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  120.894531      69.105469      20.536458   79.799479
# std       3.369578   31.972618      19.355807      15.952218  115.244002
# min       0.000000    0.000000       0.000000       0.000000    0.000000
# 25%       1.000000   99.000000      62.000000       0.000000    0.000000
# 50%       3.000000  117.000000      72.000000      23.000000   30.500000
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    31.992578                  0.471876   33.240885    0.348958
# std      7.884160                  0.331329   11.760232    0.476951
# min      0.000000                  0.078000   21.000000    0.000000
# 25%     27.300000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %%
df= df.drop_duplicates()

# %%
#reshaped data
df.shape
# Out:
# (768, 9)

# %% [markdown]
# So there is no duplicates in the dataset

# %%
#check null values to find the missing values column wise
df.isnull().sum()
# Out:
# Pregnancies                 0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Age                         0
# Outcome                     0
# dtype: int64

# %%
df.columns
# Out:
# Index(['Pregnancies', 'Glucose', 'BloodPressure', 'SkinThickness', 'Insulin',
#        'BMI', 'DiabetesPedigreeFunction', 'Age', 'Outcome'],
#       dtype='object')

# %%
print('Number of zero values in Glucose', df[df['Glucose']==0].shape[0])
print('Number of zero values in BloodPressure', df[df['BloodPressure']==0].shape[0])
print('Number of zero values in SkinThickness', df[df['SkinThickness']==0].shape[0])
print('Number of zero values in Insulin', df[df['Insulin']==0].shape[0])
print('Number of zero values in BMI', df[df['BMI']==0].shape[0])
# Out:
# Number of zero values in Glucose 5
# Number of zero values in BloodPressure 35
# Number of zero values in SkinThickness 227
# Number of zero values in Insulin 374
# Number of zero values in BMI 11

# %% [markdown]
# Replace zeros with their columns mean values

# %%
df['Glucose']=df['Glucose'].replace(0,df['Glucose'].mean())
print('Number of zero values in Glucose',df[df['Glucose']==0].shape[0])
df['BloodPressure']=df['BloodPressure'].replace(0,df['BloodPressure'].mean())
print('Number of zero values in BloodPressure',df[df['BloodPressure']==0].shape[0])
df['SkinThickness']=df['SkinThickness'].replace(0,df['SkinThickness'].mean())
print('Number of zero values in SkinThickness',df[df['SkinThickness']==0].shape[0])
df['Insulin']=df['Insulin'].replace(0,df['Insulin'].mean())
print('Number of zero values in Insulin',df[df['Insulin']==0].shape[0])
df['BMI']=df['BMI'].replace(0,df['BMI'].mean())
print('Number of zero values in BMI',df[df['BMI']==0].shape[0])
# Out:
# Number of zero values in Glucose 0
# Number of zero values in BloodPressure 0
# Number of zero values in SkinThickness 0
# Number of zero values in Insulin 0
# Number of zero values in BMI 0

# %%
df.describe()
# Out:
#        Pregnancies     Glucose  BloodPressure  SkinThickness     Insulin  \
# count   768.000000  768.000000     768.000000     768.000000  768.000000
# mean      3.845052  121.681605      72.254807      26.606479  118.660163
# std       3.369578   30.436016      12.115932       9.631241   93.080358
# min       0.000000   44.000000      24.000000       7.000000   14.000000
# 25%       1.000000   99.750000      64.000000      20.536458   79.799479
# 50%       3.000000  117.000000      72.000000      23.000000   79.799479
# 75%       6.000000  140.250000      80.000000      32.000000  127.250000
# max      17.000000  199.000000     122.000000      99.000000  846.000000
#
#               BMI  DiabetesPedigreeFunction         Age     Outcome
# count  768.000000                768.000000  768.000000  768.000000
# mean    32.450805                  0.471876   33.240885    0.348958
# std      6.875374                  0.331329   11.760232    0.476951
# min     18.200000                  0.078000   21.000000    0.000000
# 25%     27.500000                  0.243750   24.000000    0.000000
# 50%     32.000000                  0.372500   29.000000    0.000000
# 75%     36.600000                  0.626250   41.000000    1.000000
# max     67.100000                  2.420000   81.000000    1.000000

# %% [markdown]
# Data Visualisation

# %%
sns.countplot(df.Outcome)
# Out:
# <AxesSubplot:xlabel='Outcome', ylabel='count'>

# %%
sns.pairplot(df)

# %%
df.hist(bins=10,figsize=(10,10))
plt.show()

# %%
#get correlation of each features in dataset
corrmat = df.corr()
top_corr_features = corrmat.index
plt.figure(figsize=(10,10))
#plot heat map
g= sns.heatmap(df[top_corr_features].corr(),annot = True, cmap = "RdYlGn")

# %%
x=df.drop(['Outcome'],axis=1)
y=df['Outcome']

# %%
x.shape
# Out:
# (768, 8)

# %%
y.shape
# Out:
# (768,)

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=7)

# %%
x_train.shape, y_train.shape
# Out:
# ((614, 8), (614,))

# %%
x_test.shape, y_test.shape
# Out:
# ((154, 8), (154,))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
SSX = scaler.transform(x)

# %%
from sklearn.linear_model import LogisticRegression
lr=LogisticRegression(solver='liblinear', multi_class = 'ovr')
lr.fit(x_train, y_train)
# Out:
# LogisticRegression(multi_class='ovr', solver='liblinear')

# %%
lr_pred=lr.predict(x_test)

# %%
lr_pred.shape
# Out:
# (154,)

# %%
#LR
from sklearn.metrics import accuracy_score
print("Train Accuracy of LogisticRegression",lr.score(x_train, y_train)*100)
print("Accuracy (Test) score of Logistic Regression ", lr.score(x_test, y_test)*100)
print("Accuracy (Test) score of Logistic Regression ", accuracy_score(y_test,lr_pred)*100)
# Out:
# Train Accuracy of LogisticRegression 76.71009771986971
# Accuracy (Test) score of Logistic Regression  80.51948051948052
# Accuracy (Test) score of Logistic Regression  80.51948051948052

# %%
#LR
from sklearn.metrics import classification_report, confusion_matrix
cm=confusion_matrix(y_test, lr_pred)
cm
# Out:
# array([[92,  5],
#        [25, 32]], dtype=int64)

# %%
sns.heatmap(confusion_matrix(y_test, lr_pred),annot = True, fmt = 'd')
# Out:
# <AxesSubplot:>

# %%
from sklearn.metrics import classification_report
print('classification report of Logistic regression:\n', classification_report(y_test,lr_pred,digits=4))
# Out:
# classification report of Logistic regression:
#                precision    recall  f1-score   support
#
#            0     0.7863    0.9485    0.8598        97
#            1     0.8649    0.5614    0.6809        57
#
#     accuracy                         0.8052       154
#    macro avg     0.8256    0.7549    0.7703       154
# weighted avg     0.8154    0.8052    0.7936       154

# %%
from sklearn.metrics import recall_score
print ('Recall or Sensitivity_score:', recall_score(y_test,lr_pred)*100)
# Out:
# Recall or Sensitivity_score: 56.14035087719298

# %%
#confusion matrix for LR
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score,roc_curve
cm = confusion_matrix(y_test, lr_pred)

# %%
#Area Under Curve
auc = roc_auc_score (y_test, lr_pred)
print("ROC AUC SCORE of Logistic Regression is",auc)
# Out:
# ROC AUC SCORE of Logistic Regression is 0.7549285585096762

# %%
fpr,tpr,thresholds = roc_curve(y_test, lr_pred)
plt.plot(fpr,tpr,color = 'orange', label = 'ROC')
plt.plot([0,1],[0,1],color = 'darkblue', linestyle = '--',label = 'ROC curve (area = %0.2f)'% auc)
plt.xlabel('FPR')
plt.ylabel('TPR')

plt.legend()
plt.grid()
plt.show()

# %%
from sklearn.neighbors import KNeighborsClassifier
Knn = KNeighborsClassifier()
Knn.fit(x_train, y_train)
# Out:
# KNeighborsClassifier()

# %%
Knn_pred=Knn.predict(x_test)

# %%
#KNN
print("Train Accuracy of KNN",Knn.score(x_train, y_train)*100)
print("Accuracy (Test) score of KNN ", Knn.score(x_test, y_test)*100)
print("Accuracy (Test) score of KNN ", accuracy_score(y_test,Knn_pred)*100)
# Out:
# Train Accuracy of KNN 81.10749185667753
# Accuracy (Test) score of KNN  72.72727272727273
# Accuracy (Test) score of KNN  72.72727272727273

# %%
sns.heatmap(confusion_matrix(y_test, Knn_pred),annot = True, fmt = "d")
# Out:
# <AxesSubplot:>

# %%
#confusion matrix for KNN
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score,roc_curve
cm = confusion_matrix(y_test, Knn_pred)

# %%
print('Classification report of KNN:\n' , classification_report(y_test, Knn_pred, digits = 4))
# Out:
# Classification report of KNN:
#                precision    recall  f1-score   support
#
#            0     0.7570    0.8351    0.7941        97
#            1     0.6596    0.5439    0.5962        57
#
#     accuracy                         0.7273       154
#    macro avg     0.7083    0.6895    0.6951       154
# weighted avg     0.7209    0.7273    0.7208       154

# %%
#Area Under Curve
auc = roc_auc_score (y_test, Knn_pred)
print("ROC AUC SCORE of KNN is",auc)
# Out:
# ROC AUC SCORE of KNN is 0.6894555977572798

# %%
fpr,tpr,thresholds = roc_curve(y_test, Knn_pred)
plt.plot(fpr,tpr,color = 'orange', label = 'ROC')
plt.plot([0,1],[0,1],color = 'darkblue', linestyle = '--',label = 'ROC curve (area = %0.2f)'% auc)
plt.xlabel('FPR')
plt.ylabel('TPR')

plt.legend()
plt.grid()
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
nb=GaussianNB()
nb.fit(x_train, y_train)
# Out:
# GaussianNB()

# %%
nb_pred=nb.predict(x_test)

# %%
#nb
print("Train Accuracy of Naive Bayes",nb.score(x_train, y_train)*100)
print("Accuracy (Test) score of Naive Bayes ", nb.score(x_test, y_test)*100)
print("Accuracy (Test) score of Naive Bayes ", accuracy_score(y_test,nb_pred)*100)
# Out:
# Train Accuracy of Naive Bayes 74.2671009771987
# Accuracy (Test) score of Naive Bayes  74.02597402597402
# Accuracy (Test) score of Naive Bayes  74.02597402597402

# %%
#Naive bayes
#confusion matrix 
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score,roc_curve
cm = confusion_matrix(y_test, nb_pred)

print('TN {}',format(cm[0,0]))
print('FP {}',format(cm[0,1]))
print('FN {}',format(cm[1,0]))
print('TP {}',format(cm[1,1]))
print('Accuracy rate: {}'.format(np.divide(np.sum([cm[0,0], cm[1,1]]), np.sum(cm))*100))
print('Misclassification rate: {}'.format(np.divide(np.sum([cm[0,1],cm[1,0]]),np.sum(cm))*100))
# Out:
# TN {} 78
# FP {} 19
# FN {} 21
# TP {} 36
# Accuracy rate: 74.02597402597402
# Misclassification rate: 25.97402597402597

# %%
sns.heatmap(confusion_matrix(y_test, nb_pred),annot = True, fmt = "d")
# Out:
# <AxesSubplot:>

# %%
print('Classification report of NB:\n' , classification_report(y_test, nb_pred, digits = 4))
# Out:
# Classification report of NB:
#                precision    recall  f1-score   support
#
#            0     0.7879    0.8041    0.7959        97
#            1     0.6545    0.6316    0.6429        57
#
#     accuracy                         0.7403       154
#    macro avg     0.7212    0.7179    0.7194       154
# weighted avg     0.7385    0.7403    0.7393       154

# %%
#Area Under Curve
auc = roc_auc_score (y_test, nb_pred)
print("ROC AUC SCORE of NB is",auc)
fpr,tpr,thresholds = roc_curve(y_test, nb_pred)
plt.plot(fpr,tpr,color = 'orange', label = 'ROC')
plt.plot([0,1],[0,1],color = 'darkblue', linestyle = '--',label = 'ROC curve (area = %0.2f)'% auc)
plt.xlabel('FPR')
plt.ylabel('TPR')

plt.legend()
plt.grid()
plt.show()
# Out:
# ROC AUC SCORE of NB is 0.7178513293543136

# %%
from sklearn.svm import SVC
sv = SVC()
sv.fit(x_train, y_train)
# Out:
# SVC()

# %%
sv_pred=sv.predict(x_test)

# %%
#SVM
print("Train Accuracy of SVM",sv.score(x_train, y_train)*100)
print("Accuracy (Test) score of SVM ", sv.score(x_test, y_test)*100)
print("Accuracy (Test) score of SVM ", accuracy_score(y_test,sv_pred)*100)
# Out:
# Train Accuracy of SVM 76.0586319218241
# Accuracy (Test) score of SVM  75.32467532467533
# Accuracy (Test) score of SVM  75.32467532467533

# %%
#SVM
#confusion matrix 
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score,roc_curve
cm = confusion_matrix(y_test, sv_pred)

# %%
sns.heatmap(confusion_matrix(y_test, sv_pred),annot = True, fmt = "d")
# Out:
# <AxesSubplot:>

# %%
print('Classification report of NB:\n' , classification_report(y_test, sv_pred, digits = 4))
# Out:
# Classification report of NB:
#                precision    recall  f1-score   support
#
#            0     0.7360    0.9485    0.8288        97
#            1     0.8276    0.4211    0.5581        57
#
#     accuracy                         0.7532       154
#    macro avg     0.7818    0.6848    0.6935       154
# weighted avg     0.7699    0.7532    0.7286       154

# %%
#Area Under Curve
auc = roc_auc_score (y_test, sv_pred)
print("ROC AUC SCORE of SVM is",auc)
fpr,tpr,thresholds = roc_curve(y_test, sv_pred)
plt.plot(fpr,tpr,color = 'orange', label = 'ROC')
plt.plot([0,1],[0,1],color = 'darkblue', linestyle = '--',label = 'ROC curve (area = %0.2f)'% auc)
plt.xlabel('FPR')
plt.ylabel('TPR')

plt.legend()
plt.grid()
plt.show()
# Out:
# ROC AUC SCORE of SVM is 0.684753119913185

# %%
from sklearn.tree import DecisionTreeClassifier
dt=DecisionTreeClassifier()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
dt_pred=dt.predict(x_test)

# %%
#Decision tree
print("Train Accuracy of Decision Tree",dt.score(x_train, y_train)*100)
print("Accuracy (Test) score of Decision Tree ", dt.score(x_test, y_test)*100)
print("Accuracy (Test) score of Decision Tree ", accuracy_score(y_test,dt_pred)*100)
# Out:
# Train Accuracy of Decision Tree 100.0
# Accuracy (Test) score of Decision Tree  78.57142857142857
# Accuracy (Test) score of Decision Tree  78.57142857142857

# %%
#confusion matrix 
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score,roc_curve
cm = confusion_matrix(y_test, dt_pred)

# %%
sns.heatmap(confusion_matrix(y_test, dt_pred),annot = True, fmt = "d")
# Out:
# <AxesSubplot:>

# %%
print('Classification report of RF:\n' , classification_report(y_test, dt_pred, digits = 4))
# Out:
# Classification report of RF:
#                precision    recall  f1-score   support
#
#            0     0.8404    0.8144    0.8272        97
#            1     0.7000    0.7368    0.7179        57
#
#     accuracy                         0.7857       154
#    macro avg     0.7702    0.7756    0.7726       154
# weighted avg     0.7884    0.7857    0.7868       154

# %%
#Area Under Curve
auc = roc_auc_score (y_test, rf_pred)
print("ROC AUC SCORE of Decision Tree Classifier is",auc)
fpr,tpr,thresholds = roc_curve(y_test, dt_pred)
plt.plot(fpr,tpr,color = 'orange', label = 'ROC')
plt.plot([0,1],[0,1],color = 'darkblue', linestyle = '--',label = 'ROC curve (area = %0.2f)'% auc)
plt.xlabel('FPR')
plt.ylabel('TPR')

plt.legend()
plt.grid()
plt.show()
# Out:
# ROC AUC SCORE of Decision Tree Classifier is 0.7766323024054982

# %%
from sklearn.ensemble import RandomForestClassifier
rf= RandomForestClassifier(criterion = 'entropy')
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier(criterion='entropy')

# %%
rf_pred=rf.predict(x_test)

# %%
#Random Forest
print("Train Accuracy of Random Forest",rf.score(x_train, y_train)*100)
print("Accuracy (Test) score of Random Forest ", rf.score(x_test, y_test)*100)
print("Accuracy (Test) score of Random Forest ", accuracy_score(y_test,rf_pred)*100)
# Out:
# Train Accuracy of Random Forest 100.0
# Accuracy (Test) score of Random Forest  83.76623376623377
# Accuracy (Test) score of Random Forest  83.76623376623377

# %%
#Random forest
#confusion matrix 
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import accuracy_score, roc_auc_score,roc_curve
cm = confusion_matrix(y_test, rf_pred)

# %%
sns.heatmap(confusion_matrix(y_test, rf_pred),annot = True, fmt = "d")
# Out:
# <AxesSubplot:>

# %%
print('Classification report of RF:\n' , classification_report(y_test, rf_pred, digits = 4))
# Out:
# Classification report of RF:
#                precision    recall  f1-score   support
#
#            0     0.8529    0.8969    0.8744        97
#            1     0.8077    0.7368    0.7706        57
#
#     accuracy                         0.8377       154
#    macro avg     0.8303    0.8169    0.8225       154
# weighted avg     0.8362    0.8377    0.8360       154

# %%
#Area Under Curve
auc = roc_auc_score (y_test, rf_pred)
print("ROC AUC SCORE of Random Forest is",auc)
fpr,tpr,thresholds = roc_curve(y_test, rf_pred)
plt.plot(fpr,tpr,color = 'orange', label = 'ROC')
plt.plot([0,1],[0,1],color = 'darkblue', linestyle = '--',label = 'ROC curve (area = %0.2f)'% auc)
plt.xlabel('FPR')
plt.ylabel('TPR')

plt.legend()
plt.grid()
plt.show()
# Out:
# ROC AUC SCORE of Random Forest is 0.8168746608790017
